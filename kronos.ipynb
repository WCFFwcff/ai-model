# %% [markdown]
# <a href="https://colab.research.google.com/github/WCFFwcff/ai-model/blob/main/kronos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyaudio
# Out:
# ...
#   Using cached PyAudio-0.2.14.tar.gz (47 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyaudio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pyaudio
# Failed to build pyaudio
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pyaudio)

# %%
from transformers import AutoTokenizer, AutoModelWithLMHead
import datetime
import speech_recognition as sr
import pyttsx3
import kagglehub

path = kagglehub.dataset_download("grafstor/simple-dialogs-for-chatbot")

# Initialize tokenizer and model (same as before)
tokenizer = AutoTokenizer.from_pretrained("gpt2-large")
model = AutoModelWithLMHead.from_pretrained("gpt2-large")
def generate_response_and_greet(prompt):
    """Generates a response using the pre-trained GPT-2 model and adds a greeting.

    Args:
        prompt (str): The input prompt or query.

    Returns:
        str: The final response with greeting and generated text.
    """

    current_time = datetime.datetime.now()
    if current_time.hour < 12:
        greeting = "Good morning!"
    elif current_time.hour < 17:
        greeting = "Good afternoon!"
    else:
        greeting = "Good evening!"

    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_length=50)
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    response = greeting + " " + generated_text
    return response
def listen_and_respond():
    """Listens for user input, generates a response, and speaks it using TTS."""

    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        user_input = recognizer.recognize_google(audio)
        print("You said: " + user_input)

        response = generate_response_and_greet(user_input)
        print("I said: " + response)

        engine = pyttsx3.init()
        engine.say(response)
        engine.runAndWait()

    except sr.UnknownValueError:
        print("Sorry, I could not understand audio")
    except sr.RequestError as e:
        print("Request failed; {0}".format(e))
if __name__ == "__main__":
    while True:
        user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
        if user_choice == 't':
            prompt = input("Your prompt: ")
            response = generate_response_and_greet(prompt)
            print("Chatbot: " + response)
        elif user_choice == 'v':
            listen_and_respond()
        elif user_choice == 'q':
            break
        else:
            print("Invalid input. Please enter 't', 'v', or 'q'.")
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1748: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: good morning
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: Good morning! good morning' to the people of the United States.
#
# "I am here to say that we are going to make America great again," he said. "We are going to make America great again. We are going to make America great again
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: hi
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
import transformers
from transformers import AutoTokenizer, AutoModelWithLMHead
import datetime
import speech_recognition as sr
import pyttsx3
import kagglehub
import webbrowser  # Added for opening websites in response to user intent

path = kagglehub.dataset_download("grafstor/simple-dialogs-for-chatbot")

# Initialize tokenizer and model (same as before)
tokenizer = AutoTokenizer.from_pretrained("gpt2-large")
model = AutoModelWithLMHead.from_pretrained("gpt2-large")

def generate_response_and_greet(prompt):
    """Generates a response using the pre-trained GPT-2 model and adds a greeting.

    Args:
        prompt (str): The input prompt or query.

    Returns:
        str: The final response with greeting and generated text.
    """

    current_time = datetime.datetime.now()
    if current_time.hour < 12:
        greeting = "Good morning!"
    elif current_time.hour < 17:
        greeting = "Good afternoon!"
    else:
        greeting = "Good evening!"

    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_length=50)
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    response = greeting + " " + generated_text
    return response

def listen_and_respond():
    """Listens for user input, generates a response, and speaks it using TTS."""

    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        user_input = recognizer.recognize_google(audio)
        print("You said: " + user_input)

        response = generate_response_and_greet(user_input)
        print("I said: " + response)

        engine = pyttsx3.init()
        engine.say(response)
        engine.runAndWait()

        # Check for social media access intent and respond accordingly
        if "open" in user_input.lower() and ("google" in user_input.lower() or "youtube" in user_input.lower()):
            if "google" in user_input.lower():
                website = "https://www.google.com"
            else:
                website = "https://www.youtube.com"
            webbrowser.open(website)  # Open the website in response to user intent

    except sr.UnknownValueError:
        print("Sorry, I could not understand audio")
    except sr.RequestError as e:
        print("Request failed; {0}".format(e))

if __name__ == "__main__":
    while True:
        user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
        if user_choice == 't':
            prompt = input("Your prompt: ")
            response = generate_response_and_greet(prompt)
            print("Chatbot: " + response)
        elif user_choice == 'v':
            listen_and_respond()
        elif user_choice == 'q':
            break
        else:
            print("Invalid input. Please enter 't', 'v', or 'q'.")
# Out:
# ...
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: open u facebook
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: Good morning! open u facebook.com/pages/The-Cult-of-the-Cult-of-the-Cult-of-the-Cult-of-the-Cult-of-the-Cult-of-
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): open youtube
# Invalid input. Please enter 't', 'v', or 'q'.
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: youtube
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: Good morning! youtube.com/watch?v=jX2X2jX2f-Y
#
# http://www.youtube.com/watch?v=jX2X2jX2f-Y
#
# http://www.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-1977284c5296> in <cell line: 72>()
#      72 if __name__ == "__main__":
#      73     while True:
# ...

# %%
import transformers
from transformers import AutoTokenizer, AutoModelWithLMHead
import datetime
import speech_recognition as sr
import pyttsx3
import kagglehub
import webbrowser  # Added for opening websites in response to user intent

path = kagglehub.dataset_download("grafstor/simple-dialogs-for-chatbot")

# Initialize tokenizer and model (same as before)
tokenizer = AutoTokenizer.from_pretrained("gpt2-large")
model = AutoModelWithLMHead.from_pretrained("gpt2-large")

def generate_response_and_greet(prompt):
    """Generates a response using the pre-trained GPT-2 model and adds a greeting.

    Args:
        prompt (str): The input prompt or query.

    Returns:
        str: The final response with greeting and generated text.
    """

    current_time = datetime.datetime.now()
    if current_time.hour < 12:
        greeting = "Good morning!"
    elif current_time.hour < 17:
        greeting = "Good afternoon!"
    else:
        greeting = "Good evening!"

    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_length=50)
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    response = greeting + " " + generated_text
    return response

def listen_and_respond():
    """Listens for user input, generates a response, and speaks it using TTS."""

    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        user_input = recognizer.recognize_google(audio)
        print("You said: " + user_input)

        response = generate_response_and_greet(user_input)
        print("I said: " + response)

        engine = pyttsx3.init()
        engine.say(response)
        engine.runAndWait()

        # Check for social media access intent and respond accordingly
        if "open" in user_input.lower() and ("google" in user_input.lower() or "youtube" in user_input.lower()):
            if "google" in user_input.lower():
                website = "https://www.google.com"
            else:
                website = "https://www.youtube.com"
            webbrowser.open(website, new=2)  # Open the website in a new tab

    except sr.UnknownValueError:
        print("Sorry, I could not understand audio")
    except sr.RequestError as e:
        print("Request failed; {0}".format(e))

if __name__ == "__main__":
    while True:
        user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
        if user_choice == 't':
            prompt = input("Your prompt: ")
            response = generate_response_and_greet(prompt)
            print("Chatbot: " + response)
        elif user_choice == 'v':
            listen_and_respond()
        elif user_choice == 'q':
            break
        else:
            print("Invalid input. Please enter 't', 'v', or 'q'.")
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/666 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ...

# %%
import requests

def get_weather(location):
  """Fetches weather data from OpenWeatherMap API and returns a textual report.

  Args:
      location (str): User's location (city, zip code, or coordinates).

  Returns:
      str: Textual weather report, or an error message if unsuccessful.
  """

  # Replace with your OpenWeatherMap API key (obtain one from https://openweathermap.org/)
  api_key = "403435e433554b48b2851909241910 "

  # Replace with user's location or prompt for it if not available
  if not location:
      location = input("What city or zip code would you like the weather for? ")

  base_url = f"https://api.openweathermap.org/data/2.5/weather?q={location}&appid={api_key}&units=metric"  # Use metric units

  # Make an HTTP GET request
  response = requests.get(base_url)

  # Check for successful response
  if response.status_code == 200:
      # Parse JSON data
      data = response.json()
      # Extract weather information
      temp = data["main"]["temp"]
      feels_like = data["main"]["feels_like"]
      humidity = data["main"]["humidity"]
      description = data["weather"][0]["description"]

      # Generate weather report
      report = f"In {location}, the current weather is {description}. It's {temp:.1f} degrees Celsius, but it feels like {feels_like:.1f} degrees Celsius. Humidity is {humidity}%.\n"
      return report
  else:
      # Handle unsuccessful API call (e.g., invalid location, API limits reached)
      error_message = f"Sorry, I couldn't get the weather information for {location}. "
      error_message += f"Please check your location or try again later."
      return error_message

def listen_and_respond():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        user_input = recognizer.recognize_google(audio)
        print("You said: " + user_input)

        response = generate_response_and_greet(user_input)
        print("I said: " + response)

        engine = pyttsx3.init()
        engine.say(response)
        engine.runAndWait()

        # Check for social media access intent and respond accordingly
        if "open" in user_input.lower() and ("google" in user_input.lower() or "youtube" in user_input.lower()):
            if "google" in user_input.lower():
                website = "https://www.google.com"
            else:
                website = "https://www.youtube.com"
            webbrowser.open(website, new=2)  # Open the website in a new tab

    except sr.UnknownValueError:
        print("Sorry, I could not understand audio")
    except sr.RequestError as e:
        print("Request failed; {0}".format(e))
        if "weather" in user_input.lower():
          # Get user's location from conversation or ask for it explicitly
          location = "chennai,tamilnadu,india"  # Extract location from conversation (if possible)
          weather_report = get_weather(location)
          response = weather_report
          print("I said: " + response)
          # ... (same as before)

if __name__ == "__main__":
    while True:
        user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
        if user_choice == 't':
            prompt = input("Your prompt: ")
            response = generate_response_and_greet(prompt)
            print("Chatbot: " + response)
        elif user_choice == 'v':
            listen_and_respond()
        elif user_choice == 'q':
            break
        else:
            print("Invalid input. Please enter 't', 'v', or 'q'.")
# Out:
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: youtube
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: Good morning! youtube.com/watch?v=jX2X2jX2f-Y
#
# http://www.youtube.com/watch?v=jX2X2jX2f-Y
#
# http://www.
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): weather
# Invalid input. Please enter 't', 'v', or 'q'.
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: weather
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: Good morning! weather/photos-are-changing-over-the-past-40-years/ywbxvq3wv9/","target":"_self","desktopImageCrop":"left-top","mobileImageCrop":"left-
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-639f52c50f12> in <cell line: 81>()
#      81 if __name__ == "__main__":
# ...

# %%
import requests
import speech_recognition as sr
import pyttsx3
import webbrowser

def generate_response_and_greet(prompt):
    """Generates a response using a greeting and handles user queries.

    Args:
        prompt (str): The input prompt or query.

    Returns:
        str: The final response with a greeting.
    """
    import datetime
    current_time = datetime.datetime.now()
    if current_time.hour < 12:
        greeting = "Good morning!"
    elif current_time.hour < 17:
        greeting = "Good afternoon!"
    else:
        greeting = "Good evening!"

    # Generate a sample response (you can modify this to use GPT-2 or another model)
    response = greeting + " How can I assist you today?"
    return response

def listen_and_respond():
    """Listens for user input, generates a response, and speaks it using TTS."""
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        user_input = recognizer.recognize_google(audio)
        print("You said: " + user_input)

        response = generate_response_and_greet(user_input)
        print("I said: " + response)

        engine = pyttsx3.init()
        engine.say(response)
        engine.runAndWait()

        # Check for social media access intent and respond accordingly
        if "open" in user_input.lower() and ("google" in user_input.lower() or "youtube" in user_input.lower()):
            if "google" in user_input.lower():
                website = "https://www.google.com"
            else:
                website = "https://www.youtube.com"
            webbrowser.open(website, new=2)  # Open the website in a new tab

    except sr.UnknownValueError:
        print("Sorry, I could not understand audio")
    except sr.RequestError as e:
        print("Request failed; {0}".format(e))

if __name__ == "__main__":
    while True:
        user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
        if user_choice == 't':
            prompt = input("Your prompt: ")
            response = generate_response_and_greet(prompt)
            print("Chatbot: " + response)
        elif user_choice == 'v':
            listen_and_respond()
        elif user_choice == 'q':
            break
        else:
            print("Invalid input. Please enter 't', 'v', or 'q'.")
# Out:
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: how was the  day
# Chatbot: Good morning! How can I assist you today?
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: news
# Chatbot: Good morning! How can I assist you today?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-31d7911f6152> in <cell line: 59>()
#      59 if __name__ == "__main__":
#      60     while True:
# ---> 61         user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
#      62         if user_choice == 't':
#      63             prompt = input("Your prompt: ")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# ...

# %%
import speech_recognition as sr
import pyttsx3
import kagglehub
import webbrowser

path = kagglehub.dataset_download("grafstor/simple-dialogs-for-chatbot")

# Initialize tokenizer and model (same as before)
tokenizer = AutoTokenizer.from_pretrained("gpt2-large")
model = AutoModelWithLMHead.from_pretrained("gpt2-large")


def generate_response_and_greet(prompt):
    """Generates a response using the pre-trained GPT-2 model and adds a greeting.

    Args:
        prompt (str): The input prompt or query.

    Returns:
        str: The final response with greeting and generated text.
    """

    current_time = datetime.datetime.now()
    if current_time.hour < 12:
        greeting = "Good morning!"
    elif current_time.hour < 17:
        greeting = "Good afternoon!"
    else:
        greeting = "Good evening!"

    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_length=50)
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    response = greeting + " " + generated_text
    return response


def listen_and_respond():
    """Listens for user input, generates a response, and speaks it using TTS."""

    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        user_input = recognizer.recognize_google(audio)
        print("You said: " + user_input)

        response = generate_response_and_greet(user_input)
        print("I said: " + response)

        engine = pyttsx3.init()
        engine.say(response)
        engine.runAndWait()

        # Check for social media access intent and respond accordingly (weather functionality removed)
        if "open" in user_input.lower() and ("google" in user_input.lower() or "youtube" in user_input.lower()):
            if "google" in user_input.lower():
                website = "https://www.google.com"
            else:
                website = "https://www.youtube.com"
            webbrowser.open(website, new=2)  # Open the website in a new tab

    except sr.UnknownValueError:
        print("Sorry, I could not understand audio")
    except sr.RequestError as e:
        print("Request failed; {0}".format(e))


if __name__ == "__main__":
    while True:
        user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
        if user_choice == 't':
            prompt = input("Your prompt: ")
            response = generate_response_and_greet(prompt)
            print("Chatbot: " + response)
        elif user_choice == 'v':
            listen_and_respond()
        elif user_choice == 'q':
            break
        else:
            print("Invalid input. Please enter 't', 'v', or 'q'.")
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1748: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: hi buddy
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
import transformers
import speech_recognition as sr
import pyttsx3
import kagglehub
import webbrowser
# Add this section after importing libraries
def load_text_responses(filename):
  """Loads responses from a text file."""
  with open(filename, 'r') as f:
    return [line.strip() for line in f.readlines()]

responses = load_text_responses("resp.txt")  # Replace with your filename
# Download latest version
#path = kagglehub.dataset_download("hijest/cleaned-data-for-the-chatbot-collected-from-movies")
#print("Path to dataset files:", path)
# Initialize tokenizer and model (replace with appropriate model names/paths)
tokenizer = transformers.AutoTokenizer.from_pretrained("gpt2")
model = transformers.AutoModelWithLMHead.from_pretrained("gpt2")  # Load pre-trained model

def generate_response_and_greet(prompt):
    """Generates a response using a greeting and leverages the pre-trained model.

    Args:
        prompt (str): The input prompt or query.

    Returns:
        str: The final response with greeting and the model-generated text.
    """

    current_time = datetime.datetime.now()
    greeting = get_greeting(current_time)  # Function to personalize greeting based on time

    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_length=50)  # Generate response with the model
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    response = greeting + " " + generated_text
    return response

def get_greeting(current_time):
    """Returns a personalized greeting based on the time of day."""

    if current_time.hour < 12:
        return "Good morning!"
    elif current_time.hour < 17:
        return "Good afternoon!"
    else:
        return "Good evening!"

def listen_and_respond():
    """Listens for user input, generates a response, and speaks it using TTS."""

    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        user_input = recognizer.recognize_google(audio)
        print("You said: " + user_input)

        response = generate_response_and_greet(user_input)
        print("I said: " + response)

        engine = pyttsx3.init()
        engine.say(response)
        engine.runAndWait()

        # Check for social media access intent and respond accordingly
        if "open" in user_input.lower() and ("google" in user_input.lower() or "youtube" in user_input.lower()):
            if "google" in user_input.lower():
                website = "https://www.google.com"
            else:
                website = "https://www.youtube.com"
            webbrowser.open(website, new=2)  # Open the website in a new tab

    except sr.UnknownValueError:
        print("Sorry, I could not understand audio")
    except sr.RequestError as e:
        print("Request failed; {0}".format(e))


if __name__ == "__main__":
    while True:
        user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
        if user_choice == 't':
            prompt = input("Your prompt: ")
            response = generate_response_and_greet(prompt)
            print("Chatbot: " + response)
        elif user_choice == 'v':
            listen_and_respond()
        elif user_choice == 'q':
            break
        else:
            print("Invalid input. Please enter 't', 'v', or 'q'.")
# Out:
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: hi
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot: Good morning! hi, who was born in the city of Kolkata, was a member of the Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolkata-based Kolk
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-b7dcebd7e0a7> in <cell line: 83>()
#      83 if __name__ == "__main__":
#      84     while True:
# ---> 85         user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
#      86         if user_choice == 't':
#      87             prompt = input("Your prompt: ")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %%
# !pip install speechrecognition
# !pip install pyttsx3
import transformers
import speech_recognition as sr
import pyttsx3
import webbrowser
import datetime

# Add this section after importing libraries
#\def load_text_responses(filename):
   # """Loads responses from a text file."""
  #  with open(filename, 'r') as f:
 #       return [line.strip() for line in f.readlines()]

#responses = load_text_responses("resp.txt")  # Replace with your filename

# Initialize tokenizer and model (replace with appropriate model names/paths)
tokenizer = transformers.AutoTokenizer.from_pretrained("gpt2")
model = transformers.AutoModelWithLMHead.from_pretrained("gpt2")  # Load pre-trained model

def generate_response_and_greet(prompt):
    """Generates a response using a greeting and leverages the pre-trained model.

    Args:
        prompt (str): The input prompt or query.

    Returns:
        str: The final response with greeting and the model-generated text.
    """

    current_time = datetime.datetime.now()
    greeting = get_greeting(current_time)  # Function to personalize greeting based on time

    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_length=50)  # Generate response with the model
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    response = greeting + " " + generated_text
    return response

def get_greeting(current_time):
    """Returns a personalized greeting based on the time of day."""

    if current_time.hour < 12:
        return "Good morning!"
    elif current_time.hour < 17:
        return "Good afternoon!"
    else:
        return "Good evening!"

def listen_and_respond():
    """Listens for user input, generates a response, and speaks it using TTS."""

    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        user_input = recognizer.recognize_google(audio)
        print("You said: " + user_input)

        response = generate_response_and_greet(user_input)
        print("I said: " + response)

        engine = pyttsx3.init()
        engine.say(response)
        engine.runAndWait()

        # Check for social media access intent and respond accordingly
        if "open" in user_input.lower() and ("google" in user_input.lower() or "youtube" in user_input.lower()):
            if "google" in user_input.lower():
                website = "https://www.google.com"
            else:
                website = "https://www.youtube.com"
            webbrowser.open(website, new=2)  # Open the website in a new tab

    except sr.UnknownValueError:
        print("Sorry, I could not understand audio")
    except sr.RequestError as e:
        print("Request failed; {0}".format(e))


if __name__ == "__main__":
    while True:
        user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
        if user_choice == 't':
            prompt = input("Your prompt: ")
            response = generate_response_and_greet(prompt)
            print("Chatbot: " + response)
        elif user_choice == 'v':
            listen_and_respond()
        elif user_choice == 'q':
            break
        else:
            print("Invalid input. Please enter 't', 'v', or 'q'.")
#no kaggle
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1748: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: hi
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
# !pip install speechrecognition
# !pip install pyttsx3
import transformers
import speech_recognition as sr
import pyttsx3
import webbrowser
import datetime
import os

def load_text_responses(filename):
    """Loads responses from a text file.

    Args:
        filename (str): The name of the text file containing pre-defined responses.

    Returns:
        list: A list of pre-defined responses loaded from the text file.
    """

    with open(filename, 'r') as f:
        return [line.strip() for line in f.readlines()]

def save_conversation(prompt, response, filename="conversation.txt", mode="a"):
    """Saves the user prompt and chatbot response to a text file.

    Args:
        prompt (str): The user's input prompt.
        response (str): The chatbot's generated response.
        filename (str, optional): The name of the text file to save the conversation.
            Defaults to "conversation.txt". Defaults to the current working directory.
        mode (str, optional): The mode for opening the file. Defaults to "a" (append).
    """

    # Get the current working directory (optional: allow user to specify a path)
    current_dir = os.getcwd()
    filepath = os.path.join(current_dir, filename)  # Construct the full file path

    with open(filepath, mode) as f:
        f.write(f"User: {prompt}\nChatbot: {response}\n\n")

def get_greeting(current_time):
    """Returns a personalized greeting based on the time of day.

    Args:
        current_time (datetime.datetime): The current time as a datetime object.

    Returns:
        str: A greeting appropriate for the time of day.
    """

    if current_time.hour < 12:
        return "Good morning!"
    elif current_time.hour < 17:
        return "Good afternoon!"
    else:
        return "Good evening!"

def generate_response_and_greet(prompt):
    """Generates a response using a greeting and leverages the pre-trained model.

    Args:
        prompt (str): The user's input prompt or query.

    Returns:
        str: The final response with greeting and the model-generated text.
    """

    current_time = datetime.datetime.now()
    greeting = get_greeting(current_time)

    # (Replace with appropriate model names/paths)
    tokenizer = transformers.AutoTokenizer.from_pretrained("gpt2")
    model = transformers.AutoModelWithLMHead.from_pretrained("gpt2")

    inputs = tokenizer(prompt, return_tensors="pt")
    outputs = model.generate(**inputs, max_length=50)
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    response = greeting + " " + generated_text
    save_conversation(prompt, response)  # Save conversation to file

    return response

def listen_and_respond():
    """Listens for user input, generates a response, and speaks it using TTS."""

    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        user_input = recognizer.recognize_google(audio)
        print("You said: " + user_input)
        response = generate_response_and_greet(user_input)
        print("I said: " + response)

        engine = pyttsx3.init()
        engine.say(response)
        engine.runAndWait()

        if "open" in user_input.lower() and ("google" in user_input.lower() or "youtube" in user_input.lower()):
            if "google" in user_input.lower():
                website = "https://www.google.com"
            else:
                website = "https://www.youtube.com"
            webbrowser.open(website, new=2)  # Open website in a new tab

    except sr.UnknownValueError:
        print("Sorry, I could not understand audio")
    except sr.RequestError as e:
        print("Request failed; {0}".format(e))


if __name__ == "__main__":
    while True:
        user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
        if user_choice == 't':
            prompt = input("Your prompt: ")
            response = generate_response_and_greet(prompt)
            print("Chatbot: " + response)
        elif user_choice == 'v':
            listen_and_respond()
        elif user_choice == 'q':
            break
        else:
            print("Invalid input. Please enter 't', 'v', or 'q'.")
#no kaggle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 24.0 MB/s eta 0:00:00
# ...
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: hi how are you
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# ...

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration
import torch

# Load the model and tokenizer
model_path = "MichalMlodawski/negative-prompt-generator-large"
tokenizer = T5Tokenizer.from_pretrained(model_path)
model = T5ForConditionalGeneration.from_pretrained(model_path)

def generate_negative_prompt(prompt, min_length=10, length_penalty=2.0, num_beams=4, max_length=512):
    """Generates a negative prompt using the provided T5 model.

    Args:
        prompt (str): The input prompt to generate the negative prompt from.
        min_length (int, optional): The minimum length of the generated negative prompt. Defaults to 10.
        length_penalty (float, optional): The length penalty coefficient. Defaults to 2.0.
        num_beams (int, optional): The number of beams for beam search. Defaults to 4.
        max_length (int, optional): The maximum length of the generated negative prompt. Defaults to 512.

    Returns:
        str: The generated negative prompt.
    """

    input_ids = tokenizer(f"Generate negative prompt using this: {prompt}", return_tensors="pt").input_ids

    # Dynamically calculate max_length based on input length
    input_length = input_ids.shape[1]
    max_length = min(input_length * 2, max_length)

    outputs = model.generate(
        input_ids,
        max_length=max_length,
        min_length=min_length,
        length_penalty=length_penalty,
        num_beams=num_beams,
        early_stopping=True
    )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# Example usage
prompt = "A photo of a cat sitting on a table"
negative_prompt = generate_negative_prompt(prompt)
print(negative_prompt)
# Out:
# low res, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality,

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration
import torch
import transformers
import speech_recognition as sr
import pyttsx3
import webbrowser
import datetime
import os

# Load the T5 model and tokenizer for negative prompt generation
model_path_negative_prompt = "MichalMlodawski/negative-prompt-generator-large"
tokenizer_negative_prompt = T5Tokenizer.from_pretrained(model_path_negative_prompt)
model_negative_prompt = T5ForConditionalGeneration.from_pretrained(model_path_negative_prompt)

# Load the GPT-2 model and tokenizer for response generation
model_path_gpt2 = "gpt2"  # Replace with the appropriate path for your fine-tuned GPT-2 model
tokenizer_gpt2 = transformers.AutoTokenizer.from_pretrained(model_path_gpt2)
model_gpt2 = transformers.AutoModelWithLMHead.from_pretrained(model_path_gpt2)
def load_text_responses(filename):
    """Loads responses from a text file.

    Args:
        filename (str): The name of the text file containing pre-defined responses.

    Returns:
        list: A list of pre-defined responses loaded from the text file.
    """

    with open(filename, 'r') as f:
        return [line.strip() for line in f.readlines()]
def save_conversation(prompt, response, filename="conversation.txt", mode="a"):
    """Saves the user prompt and chatbot response to a text file.

    Args:
        prompt (str): The user's input prompt.
        response (str): The chatbot's generated response.
        filename (str, optional): The name of the text file to save the conversation.
            Defaults to "conversation.txt". Defaults to the current working directory.
        mode (str, optional): The mode for opening the file. Defaults to "a" (append).
    """

    # Get the current working directory (optional: allow user to specify a path)
    current_dir = os.getcwd()
    filepath = os.path.join(current_dir, filename)  # Construct the full file path

    with open(filepath, mode) as f:
        f.write(f"User: {prompt}\nChatbot: {response}\n\n")



def get_greeting(current_time):
    """Returns a personalized greeting based on the time of day.

    Args:
        current_time (datetime.datetime): The current time as a datetime object.

    Returns:
        str: A greeting appropriate for the time of day.
    """

    if current_time.hour < 12:
        return "Good morning!"
    elif current_time.hour < 17:
        return "Good afternoon!"
    else:
        return "Good evening!"

def generate_negative_prompt(prompt, min_length=10, length_penalty=2.0, num_beams=4, max_length=512):
    """Generates a negative prompt using the provided T5 model.

    Args:
        prompt (str): The input prompt to generate the negative prompt from.
        min_length (int, optional): The minimum length of the generated negative prompt. Defaults to 10.
        length_penalty (float, optional): The length penalty coefficient. Defaults to 2.0.
        num_beams (int, optional): The number of beams for beam search. Defaults to 4.
        max_length (int, optional): The maximum length of the generated negative prompt. Defaults to 512.

    Returns:
        str: The generated negative prompt.
    """

    input_ids = tokenizer(f"Generate negative prompt using this: {prompt}", return_tensors="pt").input_ids

    # Dynamically calculate max_length based on input length
    input_length = input_ids.shape[1]
    max_length = min(input_length * 2, max_length)

    outputs = model.generate(
        input_ids,
        max_length=max_length,
        min_length=min_length,
        length_penalty=length_penalty,
        num_beams=num_beams,
        early_stopping=True
    )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

def generate_response_and_greet(prompt):
    """Generates a response using a greeting, leverages GPT-2, and optionally uses a negative prompt.

    Args:
        prompt (str): The user's input prompt or query.

    Returns:
        str: The final response with greeting and the model-generated text.
    """

    current_time = datetime.datetime.now()
    greeting = get_greeting(current_time)

    # Use the user prompt to generate a negative prompt (optional)
    negative_prompt = None
    use_negative_prompt = True  # Set to True to enable negative prompt generation
    if use_negative_prompt:
        negative_prompt = generate_negative_prompt(prompt)

    # Generate response using GPT-2
    inputs_gpt2 = tokenizer_gpt2(prompt + (f" (with negative prompt: {negative_prompt})" if negative_prompt else ""), return_tensors="pt")
    outputs_gpt2 = model_gpt2.generate(**inputs_gpt2, max_length=50)
    generated_text_gpt2 = tokenizer_gpt2.decode(outputs_gpt2[0], skip_special_tokens=True)

    response = greeting + " " + generated_text_gpt2
    save_conversation(prompt, response)  # Save conversation to file

    return response

def listen_and_respond():
    """Listens for user input, generates a response, and speaks it using TTS."""

    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        user_input = recognizer.recognize_google(audio)
        print("You said: " + user_input)
        response = generate_response_and_greet(user_input)
        print("I said: " + response)

        engine = pyttsx3.init()
        engine.say(response)
        engine.runAndWait()

        if "open" in user_input.lower() and ("google" in user_input.lower() or "youtube" in user_input.lower()):
            if "google" in user_input.lower():
                website = "https://www.google.com"
            else:
                website = "https://www.youtube.com"
            webbrowser.open(website, new=2)  # Open website in a new tab

    except sr.UnknownValueError:
        print("Sorry, I could not understand audio")
    except sr.RequestError as e:
        print("Request failed; {0}".format(e))

if __name__ == "__main__":
    while True:
        user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
        if user_choice == 't':
            prompt = input("Your prompt: ")
            response = generate_response_and_greet(prompt)
            print("Chatbot: " + response)
        elif user_choice == 'v':
            listen_and_respond()
        elif user_choice == 'q':
            break
        else:
            print("Invalid input. Please enter 't', 'v', or 'q'.")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1748: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: hi
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ...

# %%
import speech_recognition as sr
import pyttsx3
import webbrowser
import datetime
import os

def load_text_responses(filename):
    """Loads responses from a text file.

    Args:
        filename (str): The name of the text file containing pre-defined responses.

    Returns:
        list: A list of pre-defined responses loaded from the text file.
    """

    with open(filename, 'r') as f:
        return [line.strip() for line in f.readlines()]

def save_conversation(prompt, response, filename="conversation.txt", mode="a"):
    """Saves the user prompt and chatbot response to a text file.

    Args:
        prompt (str): The user's input prompt.
        response (str): The chatbot's generated response.
        filename (str, optional): The name of the text file to save the conversation.
            Defaults to "conversation.txt". Defaults to the current working directory.
        mode (str, optional): The mode for opening the file. Defaults to "a" (append).
    """

    current_dir = os.getcwd()
    filepath = os.path.join(current_dir, filename)  # Construct the full file path

    with open(filepath, mode) as f:
        f.write(f"User: {prompt}\nChatbot: {response}\n\n")

def get_greeting(current_time):
    """Returns a personalized greeting based on the time of day.

    Args:
        current_time (datetime.datetime): The current time as a datetime object.

    Returns:
        str: A greeting appropriate for the time of day.
    """

    if current_time.hour < 12:
        return "Good morning!"
    elif current_time.hour < 17:
        return "Good afternoon!"
    else:
        return "Good evening!"

def generate_response_and_greet(prompt):
    """Generates a response using a greeting.

    Args:
        prompt (str): The user's input prompt or query.

    Returns:
        str: The final response with greeting.
    """

    current_time = datetime.datetime.now()
    greeting = get_greeting(current_time)

    # Response generation logic (pre-defined or simple echo response)
    response = greeting + " You said: " + prompt

    save_conversation(prompt, response)  # Save conversation to file

    return response

def listen_and_respond():
    """Listens for user input, generates a response, and speaks it using TTS."""

    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        user_input = recognizer.recognize_google(audio)
        print("You said: " + user_input)
        response = generate_response_and_greet(user_input)
        print("I said: " + response)

        engine = pyttsx3.init()
        engine.say(response)
        engine.runAndWait()

        if "open" in user_input.lower() and ("google" in user_input.lower() or "youtube" in user_input.lower()):
            if "google" in user_input.lower():
                website = "https://www.google.com"
            else:
                website = "https://www.youtube.com"
            webbrowser.open(website, new=2)  # Open website in a new tab

    except sr.UnknownValueError:
        print("Sorry, I could not understand audio")
    except sr.RequestError as e:
        print("Request failed; {0}".format(e))

if __name__ == "__main__":
    while True:
        user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
        if user_choice == 't':
            prompt = input("Your prompt: ")
            response = generate_response_and_greet(prompt)
            print("Chatbot: " + response)
        elif user_choice == 'v':
            listen_and_respond()
        elif user_choice == 'q':
            break
        else:
            print("Invalid input. Please enter 't', 'v', or 'q'.")
# Out:
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: hi
# Chatbot: Good morning! You said: hi
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): how are you
# Invalid input. Please enter 't', 'v', or 'q'.
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: how are you
# Chatbot: Good morning! You said: how are you
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-ee612555754c> in <cell line: 104>()
#     104 if __name__ == "__main__":
#     105     while True:
# --> 106         user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
#     107         if user_choice == 't':
#     108             prompt = input("Your prompt: ")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %%
import speech_recognition as sr
import pyttsx3
import webbrowser
import datetime
import os
import random

def load_text_responses(filename="resp.txt"):
    """Loads responses from a text file.

    Args:
        filename (str): The name of the text file containing pre-defined responses.

    Returns:
        list: A list of pre-defined responses loaded from the text file.
    """

    with open(filename, 'r') as f:
        return [line.strip() for line in f.readlines()]

def save_conversation(prompt, response, filename="conversation.txt", mode="a"):
    """Saves the user prompt and chatbot response to a text file.

    Args:
        prompt (str): The user's input prompt.
        response (str): The chatbot's generated response.
        filename (str, optional): The name of the text file to save the conversation.
            Defaults to "conversation.txt". Defaults to the current working directory.
        mode (str, optional): The mode for opening the file. Defaults to "a" (append).
    """

    current_dir = os.getcwd()
    filepath = os.path.join(current_dir, filename)  # Construct the full file path

    with open(filepath, mode) as f:
        f.write(f"User: {prompt}\nChatbot: {response}\n\n")

def get_greeting(current_time):
    """Returns a personalized greeting based on the time of day.

    Args:
        current_time (datetime.datetime): The current time as a datetime object.

    Returns:
        str: A greeting appropriate for the time of day.
    """

    if current_time.hour < 12:
        return "Good morning!"
    elif current_time.hour < 17:
        return "Good afternoon!"
    else:
        return "Good evening!"

def generate_response_and_greet(prompt, responses):
    """Generates a response using a greeting and selects from pre-defined responses.

    Args:
        prompt (str): The user's input prompt or query.
        responses (list): A list of pre-defined responses from the file.

    Returns:
        str: The final response with greeting.
    """

    current_time = datetime.datetime.now()
    greeting = get_greeting(current_time)

    # Select a random response from the pre-loaded responses
    response = random.choice(responses)

    full_response = greeting + " " + response
    save_conversation(prompt, full_response)  # Save conversation to file

    return full_response

def listen_and_respond(responses):
    """Listens for user input, generates a response, and speaks it using TTS."""

    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        user_input = recognizer.recognize_google(audio)
        print("You said: " + user_input)
        response = generate_response_and_greet(user_input, responses)
        print("I said: " + response)

        engine = pyttsx3.init()
        engine.say(response)
        engine.runAndWait()

        if "open" in user_input.lower() and ("google" in user_input.lower() or "youtube" in user_input.lower()):
            if "google" in user_input.lower():
                website = "https://www.google.com"
            else:
                website = "https://www.youtube.com"
            webbrowser.open(website, new=2)  # Open website in a new tab

    except sr.UnknownValueError:
        print("Sorry, I could not understand audio")
    except sr.RequestError as e:
        print("Request failed; {0}".format(e))

if __name__ == "__main__":
    # Load responses from 'resp.txt' file
    responses = load_text_responses("resp.txt")

    while True:
        user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
        if user_choice == 't':
            prompt = input("Your prompt: ")
            response = generate_response_and_greet(prompt, responses)
            print("Chatbot: " + response)
        elif user_choice == 'v':
            listen_and_respond(responses)
        elif user_choice == 'q':
            break
        else:
            print("Invalid input. Please enter 't', 'v', or 'q'.")
# Out:
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: hi
# Chatbot: Good morning! "Do you believe in ghosts?","As a chatbot, I don't have beliefs, but people have varied opinions on ghosts."
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: hi how are you
# Chatbot: Good morning! "Can you solve riddles?","I can try! Give me a riddle to solve."
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-be157807e51e> in <cell line: 107>()
#     110
#     111     while True:
# --> 112         user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
#     113         if user_choice == 't':
#     114             prompt = input("Your prompt: ")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...

# %%
import speech_recognition as sr
import pyttsx3
import webbrowser
import datetime
import os

def load_text_responses(filename="resp.txt"):
    """Loads responses from a text file.

    Args:
        filename (str): The name of the text file containing pre-defined responses.

    Returns:
        dict: A dictionary where keys are keywords, and values are lists of possible responses.
    """

    responses = {}
    with open(filename, 'r') as f:
        for line in f:
            # Split keyword and response by ":"
            if ":" in line:
                keyword, response = line.strip().split(":", 1)
                keyword = keyword.strip().lower()
                if keyword in responses:
                    responses[keyword].append(response.strip())
                else:
                    responses[keyword] = [response.strip()]
    return responses

def save_conversation(prompt, response, filename="conversation.txt", mode="a"):
    """Saves the user prompt and chatbot response to a text file."""

    current_dir = os.getcwd()
    filepath = os.path.join(current_dir, filename)

    with open(filepath, mode) as f:
        f.write(f"User: {prompt}\nChatbot: {response}\n\n")

def get_greeting(current_time):
    """Returns a personalized greeting based on the time of day."""

    if current_time.hour < 12:
        return "Good morning!"
    elif current_time.hour < 17:
        return "Good afternoon!"
    else:
        return "Good evening!"

def generate_response_and_greet(prompt, responses):
    """Generates a response by matching keywords in the user input."""

    current_time = datetime.datetime.now()
    greeting = get_greeting(current_time)

    # Find the best matching response
    prompt_lower = prompt.lower()
    response = "Sorry, I don't have an answer for that."

    for keyword, resp_list in responses.items():
        if keyword in prompt_lower:
            response = random.choice(resp_list)
            break

    full_response = greeting + " " + response
    save_conversation(prompt, full_response)

    return full_response

def listen_and_respond(responses):
    """Listens for user input, generates a response, and speaks it using TTS."""

    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = recognizer.listen(source)

    try:
        user_input = recognizer.recognize_google(audio)
        print("You said: " + user_input)
        response = generate_response_and_greet(user_input, responses)
        print("I said: " + response)

        engine = pyttsx3.init()
        engine.say(response)
        engine.runAndWait()

        if "open" in user_input.lower() and ("google" in user_input.lower() or "youtube" in user_input.lower()):
            if "google" in user_input.lower():
                website = "https://www.google.com"
            else:
                website = "https://www.youtube.com"
            webbrowser.open(website, new=2)  # Open website in a new tab

    except sr.UnknownValueError:
        print("Sorry, I could not understand audio")
    except sr.RequestError as e:
        print("Request failed; {0}".format(e))

if __name__ == "__main__":
    # Load responses from 'resp.txt' file
    responses = load_text_responses("resp.txt")

    while True:
        user_choice = input("Enter 't' for text input or 'v' for voice input (or 'q' to quit): ")
        if user_choice == 't':
            prompt = input("Your prompt: ")
            response = generate_response_and_greet(prompt, responses)
            print("Chatbot: " + response)
        elif user_choice == 'v':
            listen_and_respond(responses)
        elif user_choice == 'q':
            break
        else:
            print("Invalid input. Please enter 't', 'v', or 'q'.")
# Out:
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: hi
# Chatbot: Good morning! Sorry, I don't have an answer for that.
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: help
# Chatbot: Good morning! I'm here to help, what do you need?
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: help
# Chatbot: Good morning! Feel free to ask, I’m here to support you.
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): hello
# Invalid input. Please enter 't', 'v', or 'q'.
# Enter 't' for text input or 'v' for voice input (or 'q' to quit): t
# Your prompt: hello
# Chatbot: Good morning! Hello there! How can I assist you today?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-cfd4d88ea8bd> in <cell line: 99>()
#     102
#     103     while True:
# ...
